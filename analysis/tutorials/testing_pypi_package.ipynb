# %%
from glob import glob
from scipy.io import wavfile
import pandas as pd
import matplotlib.pyplot as plt

# %%
import brainwire

# %%
data_dir = "../../data/"
data_file_l = glob(data_dir + "*.wav")
current_file = data_file_l[0]
sample_rate, data = wavfile.read(current_file)

# %%
from brainwire import encode
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from brainwire import encode
#
# ImportError: cannot import name 'encode' from 'brainwire' (/Volumes/T7/Github/Neuralink-Compression-Challenge/py_encoding_env/lib/python3.11/site-packages/brainwire/__init__.py)

# %%
from brainwire import decode

# %%
compressed_data = encode.compress(current_file)

# %%
sample_rate, data_brainwire = decode.decompress(compressed_data)

# %%
data_brainwire_pd = pd.DataFrame(data_brainwire)

# %%
sample_rate, data = wavfile.read(current_file)

# %%
data_wavfile = pd.DataFrame(data)

# %%
plt.plot(data_wavfile)
plt.plot(data_brainwire)
plt.show()
